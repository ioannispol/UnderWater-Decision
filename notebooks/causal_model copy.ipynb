# %%
import pandas as pd
import dowhy
from dowhy import CausalModel
from sklearn.preprocessing import LabelEncoder

# Load your dataset
data = pd.read_csv('/home/ioannis/Dev/uw-decision/UnderWater-Decision/data/synthetic_dataset.csv')
le = LabelEncoder()
data['platform'] = le.fit_transform(data['platform'])
data['item'] = le.fit_transform(data['item'])
data['Recommended_Cleaning_Method'] = le.fit_transform(data['Recommended_Cleaning_Method'])

# Define the model's variables
treatment = 'depth'  # or any other variable
outcome = 'method'
common_causes = ['year', 'structure_type', 'biofouling_type', 'biofouling_extent']

causal_graph = """
digraph {
    depthmin -> hardPerc;
    depthmin -> softPerc;
    depthmax -> hardPerc;
    depthmax -> softPerc;
    year -> hardPerc;
    year -> softPerc;
    item -> hardPerc;
    item -> softPerc;
    hardPerc -> Total_Area_Coverage;
    softPerc -> Total_Area_Coverage;
    hardmm -> hardPerc;
    softmm -> softPerc;
    Total_Area_Coverage -> Recommended_Cleaning_Method;
}
"""

model = CausalModel(
    data=data,
    treatment=['depthmin', 'depthmax', 'year', 'item', 'hardmm', 'softmm'],
    outcome='Recommended_Cleaning_Method',
    graph=causal_graph
)

# %%
model.view_model()

# %%
import networkx as nx
import pygraphviz as pgv
from IPython.display import Image

# Create a directed graph
A = pgv.AGraph(directed=True)

# Add edges based on your causal model
A.add_edge('depthmin', 'hardPerc')
A.add_edge('depthmin', 'softPerc')
# ... add the rest of your edges ...

# Set graph attributes for top to bottom layout
A.graph_attr.update(rankdir="TB")

# Render the graph to a file (e.g., in .png format)
A.draw('causal_graph.png', prog='dot', format='png')

# Display the graph
Image(filename='causal_graph.png')

# %%
# Identify the causal effect
identified_estimand = model.identify_effect()

# %%
# Choose a method to estimate the causal effect (e.g., linear regression, propensity score matching)
estimate = model.estimate_effect(identified_estimand, method_name="backdoor.linear_regression")
# Out:
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]

# %%
print(estimate)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#                         d
# ─────────────────────────────────────────────────(E[Recommended_Cleaning_Metho
# d[depthmin  depthmax  year  item  hardmm  softmm]
#
#
# d])
#
# Estimand assumption 1, Unconfoundedness: If U→{depthmin,depthmax,year,item,hardmm,softmm} and U→Recommended_Cleaning_Method then P(Recommended_Cleaning_Method|depthmin,depthmax,year,item,hardmm,softmm,,U) = P(Recommended_Cleaning_Method|depthmin,depthmax,year,item,hardmm,softmm,)
#
# ## Realized estimand
# b: Recommended_Cleaning_Method~depthmin+depthmax+year+item+hardmm+softmm
# Target units: ate
#
# ## Estimate
# Mean value: 0.015244937085231669

# %%
# Refute the estimate
refutation = model.refute_estimate(identified_estimand, estimate, method_name="random_common_cause")
print(refutation)
# Out:
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# Refute: Add a random common cause
# Estimated effect:0.015244937085231669
# New effect:0.015195793646675887
# p value:0.88
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]

# %%
# Example: Changing the 'treatment_variable' to a specific value
counterfactual_data = data.copy()
counterfactual_data['treatment_variable'] = 'new_value'  # Change 'new_value' to your counterfactual value

# %%
# First, identify the estimand
identified_estimand = model.identify_effect()

# Then, estimate the causal effect
causal_estimate = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.linear_regression"
)

# Now, apply the counterfactual
counterfactuals = model.counterfactuals(
    data=counterfactual_data,
    estimand=identified_estimand,
    method_name="backdoor.linear_regression"
)
# Out:
# /home/ioannis/miniconda3/envs/uw-decision/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model copy.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> causal_estimate = model.estimate_effect(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     identified_estimand,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     method_name="backdoor.linear_regression"
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> )
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # Now, apply the counterfactual
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> counterfactuals = model.counterfactuals(
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     data=counterfactual_data,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     estimand=identified_estimand,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     method_name="backdoor.linear_regression"
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/ioannis/Dev/uw-decision/UnderWater-Decision/notebooks/causal_model%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> )
#
# AttributeError: 'CausalModel' object has no attribute 'counterfactuals'

# %%
from dowhy import gcm

# Initialize the Structural Causal Model (SCM)
causal_model = gcm.StructuralCausalModel(causal_graph)

# %%
# Automatic assignment
gcm.auto.assign_causal_mechanisms(causal_model, data)

# Manual assignment (example for a single node)
causal_model.set_causal_mechanism('depthmin', gcm.EmpiricalDistribution())
# Repeat this step for each node in your graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspaces/UnderWater-Decision/notebooks/causal_model.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell://dev-container%...-Decision/notebooks/causal_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Automatic assignment
# ----> <a href='vscode-notebook-cell://dev-container%...-Decision/notebooks/causal_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> gcm.auto.assign_causal_mechanisms(causal_model, data)
#       <a href='vscode-notebook-cell://dev-container%...-Decision/notebooks/causal_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # Manual assignment (example for a single node)
#       <a href='vscode-notebook-cell://dev-container%...-Decision/notebooks/causal_model.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> causal_model.set_causal_mechanism('depthmin', gcm.EmpiricalDistribution())
#
# File /opt/miniconda/envs/uw-decision/lib/python3.10/site-packages/dowhy/gcm/auto.py:132, in assign_causal_mechanisms(causal_model, based_on, quality, override_models)
#      90 def assign_causal_mechanisms(
#      91     causal_model: ProbabilisticCausalModel,
#      92     based_on: pd.DataFrame,
#      93     quality: AssignmentQuality = AssignmentQuality.GOOD,
#      94     override_models: bool = False,
#      95 ) -> None:
#      96     """Automatically assigns appropriate causal models. If causal models are already assigned to nodes and
#      97     override_models is set to False, this function only validates the assignments with respect to the graph structure.
#      98     Here, the validation checks whether root nodes have StochasticModels and non-root ConditionalStochasticModels
#    (...)
#     130     :return: None
#     131     """
# --> 132     for node in causal_model.graph.nodes:
#     133         if not override_models and CAUSAL_MECHANISM in causal_model.graph.nodes[node]:
#     134             validate_causal_model_assignment(causal_model.graph, node)
#
# AttributeError: 'str' object has no attribute 'nodes'
